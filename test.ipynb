# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import script

# %%
def f(x):
    return np.exp(-x ** 2)

# %%
x = np.linspace(-1, 3, 100)

# %%
script.myplot(f, x)
